# %%
import matplotlib.pyplot as plt
import seaborn as sns

def erstelle_balkendiagramm(data, title, x_label, y_label, x_ticks=None):
    plt.figure(figsize=(10, 6))
    sns.barplot(x=data.index, y=data.values)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if x_ticks:
        plt.xticks(range(len(x_ticks)), x_ticks)
    plt.show()

df['Monat'] = df['Ausleihdatum'].dt.month
df['Ausleihdauer'] = (df['Rückgabedatum'] - df['Ausleihdatum']).dt.days

ausleihen_nach_genre = df['Genre'].value_counts()
ausleihen_nach_monat = df.groupby('Monat').size()
durchschnittliche_ausleihdauer_nach_genre = df.groupby('Genre')['Ausleihdauer'].mean()

erstelle_balkendiagramm(ausleihen_nach_genre, 'Ausleihhäufigkeit nach Genre', 'Genre', 'Anzahl der Ausleihen')
erstelle_balkendiagramm(ausleihen_nach_monat, 'Saisonale Trends in den Ausleihen', 'Monat', 'Anzahl der Ausleihen',
                        ['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez'])
erstelle_balkendiagramm(durchschnittliche_ausleihdauer_nach_genre, 'Durchschnittliche Ausleihdauer nach Genre', 'Genre', 'Durchschnittliche Ausleihdauer (Tage)')
